# %%
# !python -m pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\darsh\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\darsh\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp312-cp312-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.7 MB 2.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.7 MB 3.3 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.7 MB 3.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 3.6 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.7 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.7 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 3.0 MB/s eta 0:00:00
# Downloading numpy-2.4.1-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/12.3 MB 7.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.3 MB 5.4 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.3 MB 5.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/12.3 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.3 MB 3.8 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.3 MB 3.8 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.3 MB 4.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.3 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.3 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.3 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 4.3 MB/s eta 0:00:00
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.4.1 pandas-3.0.0 tzdata-2025.3
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Load datasets
fake_df = pd.read_csv("../data/raw/Fake.csv")
true_df = pd.read_csv("../data/raw/True.csv")

# Add labels
fake_df["label"] = 0   # Fake news
true_df["label"] = 1   # Real news

# Combine datasets
df = pd.concat([fake_df, true_df], axis=0)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Basic info
print(df.shape)
print(df["label"].value_counts())
# Out:
# (44898, 5)
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
# Save processed dataset
df.to_csv("../data/processed/news_labeled.csv", index=False)
